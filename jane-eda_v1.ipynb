# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jane-street-market-prediction/example_sample_submission.csv
# /kaggle/input/jane-street-market-prediction/features.csv
# /kaggle/input/jane-street-market-prediction/example_test.csv
# /kaggle/input/jane-street-market-prediction/train.csv
# /kaggle/input/jane-street-market-prediction/janestreet/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/jane-street-market-prediction/janestreet/__init__.py

# %%
import os
import gc
import pandas as pd
import numpy as np

import fastai
from   fastai.callback import *
from   fastai.callback.all import *
from   fastai.callback.training import GradientClip
from   fastai.callback.all import SaveModelCallback, EarlyStoppingCallback, ReduceLROnPlateau 
from   fastai.tabular import *
from   fastai.tabular.data import *
from   fastai.tabular.all import *
from   fastai.tabular.all import TabularPandas, RandomSplitter, CategoryBlock, MultiCategoryBlock, range_of, accuracy, tabular_learner, TabularDataLoaders
from   fastai.learner import Learner
from   fastai.metrics import RocAucMulti

from   sklearn.pipeline import Pipeline, FeatureUnion
from   sklearn.impute import SimpleImputer
from   sklearn.preprocessing import PolynomialFeatures, StandardScaler
from   sklearn.compose import ColumnTransformer
from   sklearn.ensemble import RandomForestClassifier
from   sklearn.base import BaseEstimator, TransformerMixin

import torch.nn as nn
from   torch.nn import CrossEntropyLoss, MSELoss
from   torch.nn.modules.loss import _WeightedLoss

import pickle
from   functools import partial
import warnings
warnings.filterwarnings ("ignore")

# %%
# Global Vars
TP   = None
DF   = None
DLs  = None
PIPE = None
BS   = 10000
N_FEATURES  = 0

# %%
def preprocess_data (filename='../input/jane-street-market-prediction/train.csv', df=None, isTrainData=True):
    
    global PIPE, N_FEATURES
    dtype = None
    if isTrainData:
        
        dtype = {
            'date'      : 'int64', 
            'weight'    : 'float32',
            'resp'      : 'float32',
            'ts_id'     : 'int64',  
            'feature_0' : 'float32'
        }
    else:
        
        dtype = {
            'date'      : 'int64', 
            'weight'    : 'float32',
            'feature_0' : 'float32'
        }
    for i in range (1, 130):
        k = 'feature_' + str (i)
        dtype[k] = 'float32'
    
    to   = None
    if isTrainData:
        df         = pd.read_csv (filename, dtype=dtype)
        df         = df.query ('date > 85')
        # df       = df[df['weight'] != 0].reset_index (drop = True)
        df         = df.reset_index (drop = True)
        
        resp_cols  = ['resp_1', 'resp_2', 'resp_3','resp_4', 'resp']    
        # df[:5000].to_csv (filename+'.dummy', index=False) 
        y          = np.median (np.stack ([df[c] for c in resp_cols]).T, axis=1)
        df.drop (columns=['weight', 'date', 'ts_id']+resp_cols, inplace=True)
        f_columns  = [c for c in df.columns if "feature" in c]
        PIPE       = Pipeline ([
                         ("imputer", SimpleImputer (missing_values=np.nan, strategy='mean')),
                         ("stndard", StandardScaler ()),
        ])
        X          = PIPE.fit_transform (df)                                   #;print('X.shape =', X.shape)
        f_columns  = [f"feature_{i}" for i in range (X.shape[1])]              #;print ('columns =', columns)
        df         = pd.DataFrame (np.hstack ((X, y.reshape ((-1,1)))))
        df.columns = f_columns + ['Y']
        N_FEATURES = len (f_columns)
        del X
    else:
        
        df         = df.drop (columns=['weight', 'date']).reset_index (drop = True)
        X          = PIPE.transform (df)
        df         = pd.DataFrame (X)
        df.columns = [f"feature_{i}" for i in range (X.shape[1])] 
        del X
    return df

# %%
DF = preprocess_data ()
with open ("PIPE.bin", "ab") as f:
    pickle.dump (PIPE, f)
# DF = DF.sample (DF.shape[0]//10)
Y = DF['Y']
DF.drop (columns=['Y'], inplace=True)
gc.collect ()
# Out:
# 0

# %%
DF.shape, Y.shape
# Out:
# ((1862597, 130), (1862597,))

# %%
from scipy.stats import pearsonr
UNARY_TRACKER = dict ()

def replaceFeature (unaryFuncs, df, y):
    """
    unaryFuncs: list of functions
    """
    col_corrs = []
    for colname in df.columns:
        
        data = df[colname].values
        max_corr = abs (pearsonr (data, y)[0])                  #;print (colname, 'max_corr =', max_corr)
        unaryFunc_i = -1
        for i in range (len (unaryFuncs)):
            
            unaryFunc = unaryFuncs[i]
            transformed_data = unaryFunc (data)                 #;print ('data =', data, 'transformed_data =', transformed_data)
            corr = abs (pearsonr (transformed_data, y)[0])      #;print (colname, 'transformed_data corr =', corr)
            if np.isnan (corr):
                corr = 0.0
            if corr > max_corr:
                
                df[colname] = transformed_data                  # TODO: uncomment this
                max_corr = corr                                 #;print (f'replacing by unaryFuncs[{i}]')
                unaryFunc_i = i
        if unaryFunc_i > -1:
            UNARY_TRACKER[colname] = unaryFunc_i
        col_corrs.append (max_corr)
    return col_corrs

# %%
UNARY_FUNCS = [lambda x: np.sign(x)*x**2,    lambda x: x**3,    lambda x: np.sign(x)*np.sqrt(np.abs(x)),
               lambda x: np.sign(x)*np.log(np.abs(x) + (np.abs(x)<1e-4)*1e-4),     lambda x: 1/(x + (np.abs(x)<1e-4)*1e-4) ]
col_corrs   = replaceFeature (UNARY_FUNCS, DF, Y)
mean_feat_corr = np.mean (col_corrs)
with open ('UNARY_TRACKER.bin', 'ab') as pfile:
    pickle.dump (UNARY_TRACKER, pfile)
mean_feat_corr
# Out:
# 0.010393764849193505

# %%
col_corrs = sorted (col_corrs, reverse=True)
col_corrs[:20]
# Out:
# [0.04761123881865745,
#  0.03810736876301013,
#  0.03688989009646267,
#  0.03397137364862688,
#  0.027928286567969265,
#  0.026858099622937344,
#  0.026737736264501787,
#  0.02664111740521065,
#  0.026010154728208317,
#  0.023258383576118313,
#  0.022570673997283523,
#  0.02251685141836205,
#  0.022301769912327945,
#  0.022089829609766166,
#  0.02207550957551746,
#  0.021770757742257396,
#  0.02085435532450634,
#  0.020853587347354253,
#  0.020290675808593624,
#  0.01940117393363007]

# %%
# CORR_THRESH = np.mean (col_corrs)
CORR_THRESH = np.quantile (col_corrs, 0.97)

# %% [markdown]
# # Find Correlation among features and remove highly correlated features
# DF['Y'] = Y
# corr = DF.corr(method='pearson').abs().unstack().sort_values(kind='quicksort', ascending=False).reset_index()
# DF.drop (columns=['Y'], inplace=True)
# corr.rename(columns={'level_0':'feature_A', 'level_1':'feature_B', 0:'Corr_Coeff'}, inplace=True)
# corr = corr[corr['Corr_Coeff']<=0.8]
# corr.dropna(inplace=True)
# corr.head ()

# %% [markdown]
# # Which features correlate more with the target?
# corr[corr['feature_A']=='Y'].head(10)

# %%
def add_interactions (binFuncs, df, y):
    
    bin_cols = []
    for colname1 in df.columns:
        for colname2 in df.columns:
            if colname1 == colname2:
                break                
            for i in range (len (binFuncs)):
                
                binFunc  = binFuncs[i]
                new_data = binFunc (df[colname1].values, df[colname2].values)
                corr  = abs (pearsonr (new_data, y)[0])
                # corr1 = abs (pearsonr (df[colname1].values, y)[0])
                # corr2 = abs (pearsonr (df[colname2].values, y)[0])
                if np.isnan (corr):
                    corr = 0.0
                # if corr > corr1 and corr > corr2 and corr > CORR_THRESH:
                if corr > CORR_THRESH:    
                    # insert the new colname but don't add now in the df else infinite loop
                    new_col_name = colname1+"#"+str(i)+"#"+colname2
                    bin_cols.append ((corr, new_col_name))
    
    # now add the new found cols to the df
    # for t in BIN_COLS:        
    #     colname1 = t[1].split('#')[0]
    #     colname2 = t[1].split('#')[-1]
    #     binFunc  = binFuncs[int (t[1].split('#')[1])]        
    #     df[t[1]]    = binFunc (df[colname1].values, df[colname2].values)  
    
    bin_cols.sort (reverse=True)
    bin_cols = [t[1] for t in bin_cols]
    return bin_cols

# %%
BIN_FUNCS = [lambda x,y: x+y,    lambda x,y: x-y,    lambda x,y: x*y,
             lambda x,y: x/(y + (np.abs(y)<1e-4)*1e-4),  lambda x,y: y/(x + (np.abs(x)<1e-4)*1e-4) ]
BIN_COLS  = add_interactions (BIN_FUNCS, DF, Y)

with open('BIN_COLS.bin', 'ab') as pfile:
    pickle.dump (BIN_COLS, pfile)
BIN_COLS
# Out:
# ['feature_39#0#feature_1',
#  'feature_39#0#feature_9',
#  'feature_53#0#feature_39',
#  'feature_122#0#feature_39',
#  'feature_39#0#feature_2',
#  'feature_39#0#feature_15',
#  'feature_128#0#feature_39',
#  'feature_44#2#feature_33',
#  'feature_126#0#feature_39',
#  'feature_44#2#feature_31',
#  'feature_124#0#feature_39',
#  'feature_39#0#feature_13',
#  'feature_71#0#feature_39',
#  'feature_120#0#feature_39',
#  'feature_39#0#feature_31',
#  'feature_51#1#feature_39',
#  'feature_42#0#feature_39',
#  'feature_39#0#feature_10',
#  'feature_111#2#feature_39',
#  'feature_69#0#feature_39',
#  'feature_43#0#feature_39',
#  'feature_39#0#feature_33',
#  'feature_50#1#feature_39',
#  'feature_39#0#feature_11',
#  'feature_52#1#feature_39',
#  'feature_96#2#feature_0',
#  'feature_39#0#feature_27',
#  'feature_39#0#feature_14',
#  'feature_39#0#feature_16',
#  'feature_99#0#feature_39',
#  'feature_49#1#feature_39',
#  'feature_96#0#feature_39',
#  'feature_39#0#feature_12',
#  'feature_39#0#feature_29',
#  'feature_76#1#feature_39',
#  'feature_39#0#feature_18',
#  'feature_96#2#feature_33',
#  'feature_96#2#feature_31',
#  'feature_39#0#feature_35',
#  'feature_70#0#feature_39',
#  'feature_96#3#feature_0',
#  'feature_44#2#feature_35',
#  'feature_41#1#feature_39',
#  'feature_39#0#feature_25',
#  'feature_44#0#feature_39',
#  'feature_77#1#feature_39',
#  'feature_98#0#feature_39',
#  'feature_97#0#feature_39',
#  'feature_39#0#feature_24',
#  'feature_82#1#feature_39',
#  'feature_83#1#feature_39',
#  'feature_54#0#feature_39',
#  'feature_39#0#feature_22',
#  'feature_73#1#feature_39',
#  'feature_91#1#feature_39',
#  'feature_78#1#feature_39',
#  'feature_88#1#feature_39',
#  'feature_79#1#feature_39',
#  'feature_106#0#feature_39',
#  'feature_39#0#feature_7',
#  'feature_111#0#feature_39',
#  'feature_74#1#feature_39',
#  'feature_85#1#feature_39',
#  'feature_110#2#feature_0',
#  'feature_110#0#feature_39',
#  'feature_103#0#feature_39',
#  'feature_68#1#feature_39',
#  'feature_96#2#feature_25',
#  'feature_67#1#feature_39',
#  'feature_96#2#feature_35',
#  'feature_80#1#feature_39',
#  'feature_115#1#feature_39',
#  'feature_129#0#feature_39',
#  'feature_39#0#feature_32',
#  'feature_118#1#feature_39',
#  'feature_39#0#feature_8',
#  'feature_123#0#feature_39',
#  'feature_39#0#feature_0',
#  'feature_110#3#feature_0',
#  'feature_61#1#feature_39',
#  'feature_48#1#feature_39',
#  'feature_127#0#feature_39',
#  'feature_63#0#feature_39',
#  'feature_95#2#feature_39',
#  'feature_60#1#feature_39',
#  'feature_62#0#feature_39',
#  'feature_39#0#feature_28',
#  'feature_95#1#feature_39',
#  'feature_117#2#feature_39',
#  'feature_39#0#feature_34',
#  'feature_112#0#feature_39',
#  'feature_64#1#feature_39',
#  'feature_58#1#feature_39',
#  'feature_87#1#feature_39',
#  'feature_117#1#feature_39',
#  'feature_59#1#feature_39',
#  'feature_39#0#feature_23',
#  'feature_65#1#feature_39',
#  'feature_66#1#feature_39',
#  'feature_109#0#feature_39',
#  'feature_86#0#feature_39',
#  'feature_99#2#feature_39',
#  'feature_39#0#feature_36',
#  'feature_39#0#feature_30',
#  'feature_103#1#feature_39',
#  'feature_39#0#feature_6',
#  'feature_111#1#feature_39',
#  'feature_118#0#feature_39',
#  'feature_56#1#feature_39',
#  'feature_86#2#feature_0',
#  'feature_105#0#feature_39',
#  'feature_104#0#feature_39',
#  'feature_85#0#feature_39',
#  'feature_115#0#feature_39',
#  'feature_66#0#feature_39',
#  'feature_95#0#feature_39',
#  'feature_65#0#feature_39',
#  'feature_79#0#feature_39',
#  'feature_49#0#feature_39',
#  'feature_39#1#feature_37',
#  'feature_106#1#feature_39',
#  'feature_127#1#feature_39',
#  'feature_39#1#feature_23',
#  'feature_39#1#feature_22',
#  'feature_41#2#feature_39',
#  'feature_86#3#feature_0',
#  'feature_62#1#feature_39',
#  'feature_60#0#feature_39',
#  'feature_39#1#feature_6',
#  'feature_61#0#feature_39',
#  'feature_63#1#feature_39',
#  'feature_105#1#feature_39',
#  'feature_88#0#feature_39',
#  'feature_104#1#feature_39',
#  'feature_39#1#feature_30',
#  'feature_39#1#feature_36',
#  'feature_73#0#feature_39',
#  'feature_129#1#feature_39',
#  'feature_82#0#feature_39',
#  'feature_91#0#feature_39',
#  'feature_39#1#feature_18',
#  'feature_64#0#feature_39',
#  'feature_78#0#feature_39',
#  'feature_27#0#feature_1',
#  'feature_96#2#feature_29',
#  'feature_39#1#feature_25',
#  'feature_39#1#feature_24',
#  'feature_97#1#feature_39',
#  'feature_39#1#feature_0',
#  'feature_31#0#feature_1',
#  'feature_86#1#feature_39',
#  'feature_39#1#feature_28',
#  'feature_43#2#feature_31',
#  'feature_109#1#feature_39',
#  'feature_99#1#feature_39',
#  'feature_76#0#feature_39',
#  'feature_67#0#feature_39',
#  'feature_87#0#feature_39',
#  'feature_43#2#feature_39',
#  'feature_59#0#feature_39',
#  'feature_39#1#feature_34',
#  'feature_68#0#feature_39',
#  'feature_117#0#feature_39',
#  'feature_44#2#feature_32',
#  'feature_58#0#feature_39',
#  'feature_112#1#feature_39',
#  'feature_44#2#feature_27',
#  'feature_98#2#feature_39',
#  'feature_104#2#feature_39',
#  'feature_41#0#feature_39',
#  'feature_110#2#feature_25',
#  'feature_39#1#feature_32',
#  'feature_48#0#feature_39',
#  'feature_50#0#feature_39',
#  'feature_123#1#feature_39',
#  'feature_39#1#feature_8',
#  'feature_98#2#feature_0',
#  'feature_39#1#feature_12',
#  'feature_80#0#feature_39',
#  'feature_96#2#feature_39',
#  'feature_39#1#feature_14',
#  'feature_44#2#feature_29',
#  'feature_74#0#feature_39',
#  'feature_56#0#feature_39',
#  'feature_110#1#feature_39',
#  'feature_98#3#feature_0',
#  'feature_42#2#feature_39',
#  'feature_51#0#feature_39',
#  'feature_86#2#feature_25',
#  'feature_39#1#feature_7',
#  'feature_110#2#feature_39',
#  'feature_98#2#feature_33',
#  'feature_110#2#feature_35',
#  'feature_54#1#feature_39',
#  'feature_40#0#feature_39',
#  'feature_98#1#feature_39',
#  'feature_83#0#feature_39',
#  'feature_77#0#feature_39',
#  'feature_44#1#feature_39',
#  'feature_87#2#feature_39',
#  'feature_70#1#feature_39',
#  'feature_52#0#feature_39',
#  'feature_39#1#feature_35',
#  'feature_43#2#feature_33',
#  'feature_43#1#feature_39',
#  'feature_44#2#feature_34',
#  'feature_39#1#feature_29',
#  'feature_96#1#feature_39',
#  'feature_39#0#feature_5',
#  'feature_39#1#feature_27',
#  'feature_39#1#feature_16',
#  'feature_53#0#feature_31',
#  'feature_27#0#feature_9',
#  'feature_53#0#feature_27',
#  'feature_42#1#feature_39',
#  'feature_44#2#feature_28',
#  'feature_66#2#feature_39',
#  'feature_33#0#feature_1',
#  'feature_44#2#feature_25',
#  'feature_96#2#feature_24',
#  'feature_31#0#feature_9',
#  'feature_31#0#feature_27',
#  'feature_98#2#feature_35',
#  'feature_96#2#feature_18',
#  'feature_39#1#feature_17',
#  'feature_51#1#feature_31',
#  'feature_96#2#feature_22',
#  'feature_39#1#feature_11',
#  'feature_42#2#feature_31',
#  'feature_98#2#feature_31',
#  'feature_39#1#feature_21',
#  'feature_31#0#feature_2',
#  'feature_122#0#feature_31',
#  'feature_110#2#feature_33',
#  'feature_39#1#feature_10',
#  'feature_27#0#feature_2',
#  'feature_39#1#feature_33',
#  'feature_122#0#feature_27',
#  'feature_65#2#feature_39',
#  'feature_96#2#feature_23',
#  'feature_108#2#feature_0',
#  'feature_86#2#feature_39',
#  'feature_98#2#feature_25',
#  'feature_27#0#feature_15',
#  'feature_128#0#feature_31',
#  'feature_120#1#feature_39',
#  'feature_51#1#feature_27',
#  'feature_50#1#feature_31',
#  'feature_39#0#feature_20',
#  'feature_33#0#feature_27',
#  'feature_32#1#feature_31',
#  'feature_44#2#feature_23',
#  'feature_128#0#feature_27',
#  'feature_44#2#feature_0',
#  'feature_110#2#feature_29',
#  'feature_41#2#feature_31',
#  'feature_126#0#feature_31',
#  'feature_71#1#feature_39',
#  'feature_39#1#feature_31',
#  'feature_43#2#feature_27',
#  'feature_124#0#feature_31',
#  'feature_31#0#feature_15',
#  'feature_124#1#feature_39',
#  'feature_126#0#feature_27',
#  'feature_126#1#feature_39',
#  'feature_49#1#feature_31',
#  'feature_27#0#feature_13',
#  'feature_71#0#feature_31',
#  'feature_124#0#feature_27',
#  'feature_96#2#feature_27',
#  'feature_108#3#feature_0',
#  'feature_39#1#feature_13',
#  'feature_44#2#feature_22',
#  'feature_128#1#feature_39',
#  'feature_71#0#feature_27',
#  'feature_86#2#feature_35',
#  'feature_44#2#feature_17',
#  'feature_39#1#feature_2',
#  'feature_44#2#feature_18',
#  'feature_50#1#feature_27',
#  'feature_44#3#feature_0',
#  'feature_122#1#feature_39',
#  'feature_39#1#feature_15',
#  'feature_33#0#feature_31',
#  'feature_41#2#feature_27',
#  'feature_120#0#feature_31',
#  'feature_42#0#feature_31',
#  'feature_53#0#feature_33',
#  'feature_60#2#feature_39',
#  'feature_42#2#feature_27',
#  'feature_31#0#feature_13',
#  'feature_120#0#feature_27',
#  'feature_53#1#feature_39',
#  'feature_105#2#feature_39',
#  'feature_101#2#feature_39',
#  'feature_42#0#feature_27',
#  'feature_110#2#feature_24',
#  'feature_49#1#feature_27',
#  'feature_44#2#feature_24',
#  'feature_39#1#feature_9',
#  'feature_31#0#feature_22',
#  'feature_113#2#feature_27',
#  'feature_99#0#feature_31',
#  'feature_33#0#feature_9',
#  'feature_43#0#feature_31',
#  'feature_51#1#feature_33',
#  'feature_61#2#feature_39',
#  'feature_69#0#feature_40',
#  'feature_31#0#feature_24',
#  'feature_108#2#feature_25',
#  'feature_128#2#feature_39',
#  'feature_110#2#feature_22',
#  'feature_122#0#feature_33',
#  'feature_52#1#feature_31',
#  'feature_96#2#feature_32',
#  'feature_31#0#feature_7',
#  'feature_113#2#feature_39',
#  'feature_96#2#feature_40',
#  'feature_76#1#feature_31',
#  'feature_37#1#feature_5',
#  'feature_126#2#feature_39',
#  'feature_35#0#feature_27',
#  'feature_34#1#feature_33',
#  'feature_33#0#feature_2',
#  'feature_108#2#feature_35',
#  'feature_35#0#feature_1',
#  'feature_43#0#feature_27',
#  'feature_29#0#feature_27',
#  'feature_87#2#feature_25',
#  'feature_27#0#feature_10',
#  'feature_128#0#feature_33',
#  'feature_44#2#feature_36',
#  'feature_31#0#feature_10',
#  'feature_40#0#feature_1',
#  'feature_27#0#feature_18',
#  'feature_42#2#feature_33',
#  'feature_113#2#feature_28',
#  'feature_27#0#feature_11',
#  'feature_108#2#feature_29',
#  'feature_113#2#feature_0',
#  'feature_47#1#feature_39',
#  'feature_86#2#feature_29',
#  'feature_52#1#feature_27',
#  'feature_86#2#feature_24',
#  'feature_50#1#feature_33',
#  'feature_89#2#feature_27',
#  'feature_99#0#feature_27',
#  'feature_101#2#feature_27',
#  'feature_126#0#feature_33',
#  'feature_39#0#feature_19',
#  'feature_31#0#feature_29',
#  'feature_35#0#feature_31',
#  'feature_98#2#feature_29',
#  'feature_31#0#feature_18',
#  'feature_31#0#feature_25',
#  'feature_124#0#feature_33',
#  'feature_82#1#feature_31',
#  'feature_69#0#feature_31',
#  'feature_69#0#feature_27',
#  'feature_39#1#feature_1',
#  'feature_44#2#feature_39',
#  'feature_86#2#feature_22',
#  'feature_40#1#feature_39',
#  'feature_69#1#feature_37',
#  'feature_113#3#feature_0',
#  'feature_33#0#feature_7',
#  'feature_28#0#feature_1',
#  'feature_89#2#feature_0',
#  'feature_31#0#feature_11',
#  'feature_108#2#feature_33',
#  'feature_31#0#feature_6',
#  'feature_71#0#feature_33',
#  'feature_33#0#feature_11',
#  'feature_96#2#feature_17',
#  'feature_89#2#feature_28',
#  'feature_33#0#feature_15',
#  'feature_49#1#feature_33',
#  'feature_29#0#feature_1',
#  'feature_101#2#feature_40',
#  'feature_43#2#feature_35',
#  'feature_27#0#feature_14',
#  'feature_87#2#feature_0',
#  'feature_97#0#feature_31',
#  'feature_96#0#feature_31',
#  'feature_86#2#feature_33',
#  'feature_87#3#feature_0',
#  'feature_73#1#feature_31',
#  'feature_108#2#feature_17',
#  'feature_69#1#feature_17',
#  'feature_40#0#feature_31',
#  'feature_84#2#feature_0',
#  'feature_108#2#feature_31',
#  'feature_110#2#feature_31',
#  'feature_110#2#feature_23',
#  'feature_101#2#feature_28',
#  'feature_120#0#feature_33',
#  'feature_89#3#feature_0',
#  'feature_41#2#feature_33',
#  'feature_77#1#feature_31',
#  'feature_78#1#feature_31',
#  'feature_101#2#feature_0',
#  'feature_88#1#feature_31',
#  'feature_98#2#feature_22',
#  'feature_98#2#feature_24',
#  'feature_33#0#feature_13',
#  'feature_42#0#feature_33',
#  'feature_23#1#feature_13',
#  'feature_41#1#feature_31',
#  'feature_31#0#feature_14',
#  'feature_89#2#feature_39',
#  'feature_111#2#feature_31',
#  'feature_27#0#feature_12',
#  'feature_96#0#feature_27',
#  'feature_113#2#feature_40',
#  'feature_76#1#feature_27',
#  'feature_83#1#feature_31',
#  'feature_96#2#feature_34',
#  'feature_69#0#feature_33',
#  'feature_31#0#feature_12',
#  'feature_76#1#feature_33',
#  'feature_40#0#feature_9',
#  'feature_110#2#feature_18',
#  'feature_91#1#feature_31',
#  'feature_44#0#feature_31',
#  'feature_53#0#feature_40',
#  'feature_101#3#feature_0',
#  'feature_79#1#feature_31',
#  'feature_86#2#feature_23',
#  'feature_31#0#feature_8',
#  'feature_31#0#feature_28',
#  'feature_41#1#feature_27',
#  'feature_40#0#feature_27',
#  'feature_122#2#feature_39',
#  'feature_84#3#feature_0',
#  'feature_27#0#feature_6',
#  'feature_27#0#feature_16',
#  'feature_69#1#feature_21',
#  'feature_77#2#feature_17',
#  'feature_98#0#feature_31',
#  'feature_99#0#feature_33',
#  'feature_40#0#feature_33',
#  'feature_70#0#feature_31',
#  'feature_82#1#feature_27',
#  'feature_33#0#feature_24',
#  'feature_32#0#feature_1',
#  'feature_106#0#feature_31',
#  'feature_43#0#feature_33',
#  'feature_128#2#feature_27',
#  'feature_85#1#feature_31',
#  'feature_77#1#feature_27',
#  'feature_52#1#feature_33',
#  'feature_53#0#feature_35',
#  'feature_23#1#feature_1',
#  'feature_118#2#feature_39',
#  'feature_31#0#feature_16',
#  'feature_49#1#feature_1',
#  'feature_108#2#feature_18',
#  'feature_27#0#feature_22',
#  'feature_78#1#feature_27',
#  'feature_70#0#feature_27',
#  'feature_108#2#feature_24',
#  'feature_126#2#feature_27',
#  'feature_33#0#feature_12',
#  'feature_44#0#feature_27',
#  'feature_83#1#feature_27',
#  'feature_122#0#feature_40',
#  'feature_54#0#feature_31',
#  'feature_44#2#feature_37',
#  'feature_113#2#feature_31',
#  'feature_111#2#feature_33',
#  'feature_44#2#feature_40',
#  'feature_40#0#feature_15',
#  'feature_43#4#feature_39',
#  'feature_126#2#feature_31',
#  'feature_94#1#feature_39',
#  'feature_33#0#feature_22',
#  'feature_111#0#feature_31',
#  'feature_35#0#feature_13',
#  'feature_27#0#feature_24',
#  'feature_27#0#feature_7',
#  'feature_97#0#feature_27',
#  'feature_98#0#feature_27',
#  'feature_124#2#feature_39',
#  'feature_40#0#feature_2',
#  'feature_35#0#feature_11',
#  'feature_128#0#feature_40',
#  'feature_40#0#feature_13',
#  'feature_33#0#feature_6',
#  'feature_65#2#feature_17',
#  'feature_128#2#feature_31',
#  'feature_54#0#feature_27',
#  'feature_108#2#feature_22',
#  'feature_69#0#feature_5',
#  'feature_35#0#feature_9',
#  'feature_96#2#feature_28',
#  'feature_82#1#feature_33',
#  'feature_29#0#feature_13',
#  'feature_96#2#feature_36',
#  'feature_33#0#feature_25',
#  'feature_122#0#feature_35',
#  'feature_115#1#feature_31',
#  'feature_126#0#feature_40',
#  'feature_32#0#feature_27',
#  'feature_103#0#feature_31',
#  'feature_33#0#feature_10',
#  'feature_43#2#feature_32',
#  'feature_124#0#feature_40',
#  'feature_116#2#feature_39',
#  'feature_74#1#feature_31',
#  'feature_29#0#feature_11',
#  'feature_88#2#feature_39',
#  'feature_88#1#feature_27',
#  'feature_98#2#feature_23',
#  'feature_35#0#feature_33',
#  'feature_33#0#feature_29',
#  'feature_73#1#feature_33',
#  'feature_98#2#feature_18',
#  'feature_40#1#feature_37',
#  'feature_33#0#feature_8',
#  'feature_111#0#feature_27',
#  'feature_86#2#feature_18',
#  'feature_69#0#feature_35',
#  'feature_113#2#feature_25',
#  'feature_33#0#feature_18',
#  'feature_73#1#feature_27',
#  'feature_113#2#feature_32',
#  'feature_50#1#feature_1',
#  'feature_111#2#feature_40',
#  'feature_33#0#feature_28',
#  'feature_35#0#feature_7',
#  'feature_23#1#feature_9',
#  'feature_68#1#feature_31',
#  'feature_53#0#feature_29',
#  'feature_97#0#feature_33',
#  'feature_91#1#feature_27',
#  'feature_89#2#feature_40',
#  'feature_88#1#feature_33',
#  'feature_94#0#feature_39',
#  'feature_41#2#feature_17',
#  'feature_53#0#feature_28',
#  'feature_67#1#feature_31',
#  'feature_106#0#feature_27',
#  'feature_128#0#feature_35',
#  'feature_101#2#feature_31',
#  'feature_71#0#feature_40',
#  'feature_23#1#feature_15',
#  'feature_95#2#feature_27',
#  'feature_35#0#feature_2',
#  'feature_102#0#feature_39',
#  'feature_118#1#feature_31',
#  'feature_89#2#feature_31',
#  'feature_40#0#feature_35',
#  'feature_28#0#feature_9',
#  'feature_40#0#feature_29',
#  'feature_39#1#feature_20',
#  'feature_98#2#feature_17',
#  'feature_51#1#feature_35',
#  'feature_27#0#feature_25',
#  'feature_96#0#feature_33',
#  'feature_129#0#feature_31',
#  'feature_69#0#feature_28',
#  'feature_120#0#feature_40',
#  'feature_79#1#feature_27',
#  'feature_47#0#feature_39',
#  'feature_77#1#feature_33',
#  'feature_122#2#feature_27',
#  'feature_69#0#feature_29',
#  'feature_126#0#feature_35',
#  'feature_29#0#feature_7',
#  'feature_44#2#feature_21',
#  'feature_124#0#feature_35',
#  'feature_78#1#feature_33',
#  'feature_61#1#feature_31',
#  'feature_80#1#feature_31',
#  'feature_36#1#feature_33',
#  'feature_110#0#feature_31',
#  'feature_115#1#feature_27',
#  'feature_43#2#feature_29',
#  'feature_63#0#feature_31',
#  'feature_29#0#feature_9',
#  'feature_40#0#feature_11',
#  'feature_95#2#feature_40',
#  'feature_28#0#feature_27',
#  'feature_60#1#feature_31',
#  'feature_62#0#feature_31',
#  'feature_96#2#feature_21',
#  'feature_48#1#feature_31',
#  'feature_87#2#feature_23',
#  'feature_62#4#feature_3',
#  'feature_34#0#feature_27',
#  'feature_86#2#feature_37',
#  'feature_83#1#feature_33',
#  'feature_28#1#feature_27',
#  'feature_113#2#feature_24',
#  'feature_111#2#feature_27',
#  'feature_99#2#feature_40',
#  'feature_89#2#feature_32',
#  'feature_122#0#feature_29',
#  'feature_112#2#feature_39',
#  'feature_33#0#feature_14',
#  'feature_101#2#feature_25',
#  'feature_7#0#feature_1',
#  'feature_35#0#feature_15',
#  'feature_120#2#feature_39',
#  'feature_127#0#feature_31',
#  'feature_87#2#feature_35',
#  'feature_68#1#feature_27',
#  'feature_69#1#feature_23',
#  'feature_32#0#feature_31',
#  'feature_69#0#feature_32',
#  'feature_85#1#feature_27',
#  'feature_25#1#feature_1',
#  'feature_89#2#feature_25',
#  'feature_84#2#feature_17',
#  'feature_74#1#feature_27',
#  'feature_95#1#feature_31',
#  'feature_41#1#feature_33',
#  'feature_91#1#feature_33',
#  'feature_51#1#feature_1',
#  'feature_113#2#feature_33',
#  'feature_67#1#feature_27',
#  'feature_11#0#feature_1',
#  'feature_17#1#feature_5',
#  'feature_42#0#feature_40',
#  'feature_124#2#feature_31',
#  'feature_37#1#feature_31',
#  'feature_126#2#feature_40',
#  'feature_129#0#feature_27',
#  'feature_101#2#feature_32',
#  'feature_124#2#feature_40',
#  'feature_124#2#feature_27',
#  'feature_44#0#feature_33',
#  'feature_118#1#feature_27',
#  'feature_107#2#feature_39',
#  'feature_29#0#feature_15',
#  'feature_85#1#feature_33',
#  'feature_31#0#feature_5',
#  'feature_110#0#feature_27',
#  'feature_79#1#feature_33',
#  'feature_122#2#feature_31',
#  'feature_40#0#feature_10',
#  'feature_71#0#feature_35',
#  'feature_53#2#feature_39',
#  'feature_29#0#feature_2',
#  'feature_43#2#feature_17',
#  'feature_50#1#feature_35',
#  'feature_51#1#feature_29',
#  'feature_42#2#feature_32',
#  'feature_103#0#feature_27',
#  'feature_84#2#feature_25',
#  'feature_122#0#feature_28',
#  'feature_37#1#feature_27',
#  'feature_27#0#feature_8',
#  'feature_51#1#feature_40',
#  'feature_128#0#feature_29',
#  'feature_123#0#feature_31',
#  'feature_110#2#feature_17',
#  'feature_98#0#feature_33',
#  'feature_87#2#feature_31',
#  'feature_113#2#feature_22',
#  'feature_53#0#feature_32',
#  'feature_96#2#feature_30',
#  'feature_103#1#feature_31',
#  'feature_31#1#feature_23',
#  'feature_98#2#feature_27',
#  'feature_40#1#feature_17',
#  'feature_34#1#feature_31',
#  'feature_61#1#feature_27',
#  'feature_120#0#feature_35',
#  'feature_43#0#feature_40',
#  'feature_34#0#feature_1',
#  'feature_106#0#feature_33',
#  'feature_63#0#feature_27',
#  'feature_44#2#feature_30',
#  'feature_128#2#feature_40',
#  'feature_76#1#feature_35',
#  'feature_80#1#feature_27',
#  'feature_101#2#feature_24',
#  'feature_62#0#feature_27',
#  'feature_27#1#feature_23',
#  'feature_127#0#feature_27',
#  'feature_60#1#feature_27',
#  'feature_126#0#feature_29',
#  'feature_70#0#feature_33',
#  'feature_28#0#feature_15',
#  'feature_34#0#feature_31',
#  'feature_39#0#feature_26',
#  'feature_89#2#feature_24',
#  'feature_108#2#feature_23',
#  'feature_48#1#feature_27',
#  'feature_101#2#feature_33',
#  'feature_124#0#feature_29',
#  'feature_37#1#feature_1',
#  'feature_95#1#feature_27',
#  'feature_53#2#feature_27',
#  'feature_66#2#feature_31',
#  'feature_96#2#feature_85',
#  'feature_27#0#feature_5',
#  'feature_113#2#feature_18',
#  'feature_32#0#feature_9',
#  'feature_42#0#feature_35',
#  'feature_128#0#feature_28',
#  'feature_36#1#feature_31',
#  'feature_36#1#feature_35',
#  'feature_102#1#feature_39',
#  'feature_28#0#feature_2',
#  'feature_31#0#feature_0',
#  'feature_123#0#feature_27',
#  'feature_35#0#feature_12',
#  'feature_69#0#feature_7',
#  'feature_126#2#feature_33',
#  'feature_103#1#feature_27',
#  'feature_28#0#feature_13',
#  'feature_54#0#feature_33',
#  'feature_64#1#feature_31',
#  'feature_50#1#feature_29',
#  'feature_52#1#feature_40',
#  'feature_58#1#feature_31',
#  'feature_87#2#feature_33',
#  'feature_33#0#feature_32',
#  'feature_65#2#feature_31',
#  'feature_36#0#feature_27',
#  'feature_69#0#feature_34',
#  'feature_53#2#feature_31',
#  'feature_40#0#feature_7',
#  'feature_69#0#feature_11',
#  'feature_101#2#feature_22',
#  'feature_51#2#feature_39',
#  'feature_33#0#feature_16',
#  'feature_119#2#feature_39',
#  'feature_104#2#feature_33',
#  'feature_108#2#feature_32',
#  'feature_111#1#feature_31',
#  'feature_74#1#feature_33',
#  'feature_50#1#feature_40',
#  'feature_53#1#feature_23',
#  'feature_87#1#feature_31',
#  'feature_76#1#feature_29',
#  'feature_33#0#feature_5',
#  'feature_87#2#feature_24',
#  'feature_96#2#feature_37',
#  'feature_13#0#feature_1',
#  'feature_59#1#feature_31',
#  'feature_117#1#feature_31',
#  'feature_69#0#feature_53',
#  'feature_85#0#feature_31',
#  'feature_79#0#feature_31',
#  'feature_126#0#feature_28',
#  'feature_71#0#feature_29',
#  'feature_30#0#feature_27',
#  'feature_120#2#feature_31',
#  'feature_113#2#feature_34',
#  'feature_37#1#feature_33',
#  'feature_112#0#feature_31',
#  'feature_37#1#feature_7',
#  'feature_49#1#feature_35',
#  'feature_89#2#feature_33',
#  'feature_124#0#feature_28',
#  'feature_86#2#feature_31',
#  'feature_65#1#feature_31',
#  'feature_89#2#feature_22',
#  'feature_122#0#feature_32',
#  'feature_37#1#feature_11',
#  'feature_69#1#feature_25',
#  'feature_124#2#feature_28',
#  'feature_101#2#feature_18',
#  'feature_111#0#feature_33',
#  'feature_40#0#feature_16',
#  'feature_58#2#feature_39',
#  'feature_40#0#feature_5',
#  'feature_37#1#feature_13',
#  'feature_126#2#feature_28',
#  'feature_40#0#feature_14',
#  'feature_69#0#feature_13',
#  'feature_84#2#feature_29',
#  'feature_29#0#feature_12',
#  'feature_111#2#feature_35',
#  'feature_115#1#feature_33',
#  'feature_31#1#feature_22',
#  'feature_36#0#feature_31',
#  'feature_103#0#feature_33',
#  'feature_84#2#feature_35',
#  'feature_40#0#feature_12',
#  'feature_99#0#feature_35',
#  'feature_49#1#feature_9',
#  'feature_35#0#feature_28',
#  'feature_31#1#feature_18',
#  'feature_66#1#feature_31',
#  'feature_69#1#feature_0',
#  'feature_85#0#feature_27',
#  'feature_23#1#feature_11',
#  'feature_122#0#feature_69']

# %%
len (BIN_COLS)
# Out:
# 792

# %% [markdown]
# # Inference time usage

# %%
pickle_path_dir = "."

UNARY_FUNCS = [lambda x: np.sign(x)*x**2,    lambda x: x**3,    lambda x: np.sign(x)*np.sqrt(np.abs(x)),
               lambda x: np.sign(x)*np.log(np.abs(x) + (np.abs(x)<1e-4)*1e-4),     lambda x: 1/(x + (np.abs(x)<1e-4)*1e-4) ]
BIN_FUNCS = [lambda x,y: x+y,    lambda x,y: x-y,    lambda x,y: x*y,
             lambda x,y: x/(y + (np.abs(y)<1e-4)*1e-4),  lambda x,y: y/(x + (np.abs(x)<1e-4)*1e-4) ]
with open (pickle_path_dir+"/PIPE.bin", "rb") as f:
    PIPE = pickle.load (f)
with open (pickle_path_dir+"/BIN_COLS.bin", "rb") as f:
    BIN_COLS = pickle.load (f)
with open (pickle_path_dir+"/UNARY_TRACKER.bin", "rb") as f:
    UNARY_TRACKER = pickle.load (f)

    
class EDATransformer (BaseEstimator, TransformerMixin):
    
    def __init__(self, unary_tracker, bin_cols, unary_funcs, bin_funcs, n_new_feat=500):
        
        super (EDATransformer, self).__init__()
        self.unary_tracker = unary_tracker
        self.bin_cols      = bin_cols
        self.unary_funcs   = unary_funcs
        self.bin_funcs     = bin_funcs
        self.n_new_feat    = min (n_new_feat, len (bin_cols))
        return
        
    def fit (self, X, y=None):        
        return self
    
    def transform (self, X, y=None):
        
        for colname in self.unary_tracker:
            col_idx  = int (colname.split ("_")[1])
            uf_idx   = self.unary_tracker[colname]
            X[:, col_idx] = self.unary_funcs[uf_idx] (X[:, col_idx])
        
        for i in range (self.n_new_feat):
            colname  = self.bin_cols[i]
            col_idx1 = int (colname.split ('#')[0].split ("_")[1])           #;print ('col_idx1 =', col_idx1)
            col_idx2 = int (colname.split ('#')[-1].split ("_")[1])
            binFunc  = self.bin_funcs[int (colname.split ('#')[1])]        
            X        = np.hstack ((X, binFunc (X[:, col_idx1], X[:, col_idx2]).reshape ((-1, 1))))
        return X
    
    def set_params (self, **parameters):
        for parameter, value in parameters.items ():
            setattr (self, parameter, value)
        return self

    def get_params (self, deep=True):
        params = {}
        return params

edat = EDATransformer (UNARY_TRACKER, BIN_COLS, UNARY_FUNCS, BIN_FUNCS)
PIPE = Pipeline (PIPE.steps + [('eda', edat)])

# %%
PIPE
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('stndard', StandardScaler()),
#                 ('eda', EDATransformer())])

# %%
batch = DF[:100]
batch = PIPE.transform (batch)
batch.shape
# Out:
# (100, 630)

# %%
def read_data (filename='../input/jane-street-market-prediction/train.csv', df=None, isTrainData=True):
    
    dtype = None
    if isTrainData:
        
        dtype = {
            'date'      : 'int64', 
            'weight'    : 'float32',
            'resp'      : 'float32',
            'ts_id'     : 'int64',  
            'feature_0' : 'float32'
        }
    else:
        
        dtype = {
            'date'      : 'int64', 
            'weight'    : 'float32',
            'feature_0' : 'float32'
        }
    for i in range (1, 130):
        k = 'feature_' + str (i)
        dtype[k] = 'float32'    
    to = None
    df = None
    if isTrainData:
        
        df         = pd.read_csv (filename, dtype=dtype)
        df         = df.query ('date > 85')
        df         = df[df['weight'] != 0].reset_index (drop = True)
        # df       = df.reset_index (drop = True)        
        resp_cols  = ['resp_1', 'resp_2', 'resp_3','resp_4', 'resp']    
        # df[:5000].to_csv (filename+'.dummy', index=False) 
        y          = np.stack ([(df[c] > 0).astype ('int') for c in resp_cols]).T
        df.drop (columns=['weight', 'date', 'ts_id']+resp_cols, inplace=True)
        f_columns  = [c for c in df.columns if "feature" in c]                
        df[resp_cols] = y
        df.columns = f_columns + resp_cols
        del y

        splits     = RandomSplitter (valid_pct=0.05) (range_of (df))
        to         = TabularPandas (df, cont_names=f_columns, cat_names=None, y_names=resp_cols, y_block=MultiCategoryBlock(encoded=True, vocab=resp_cols), splits=splits)
    else:
        
        df         = df.drop (columns=['weight', 'date']).reset_index (drop = True)
        # X          = PIPE.transform (df)        
        # df.columns = [f"feature_{i}" for i in range (X.shape[1])] 
    return to, df
